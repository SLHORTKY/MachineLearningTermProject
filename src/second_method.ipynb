# %%
import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use("ggplot")

import sklearn
from sklearn.decomposition import TruncatedSVD

# %%
data_path = "../Data/ratings.csv"
df = pd.read_csv(data_path)


popular_products = pd.DataFrame(df.groupby('ProductId')['Rating'].count())
most_popular = popular_products.sort_values('Rating', ascending=False)

# %%
subset_df = df.head(10000)
ratings_utility_matrix = subset_df.pivot_table(values='Rating', index='UserId', columns='ProductId', fill_value=0)
ratings_utility_matrix.head()
# Out:
# ProductId              0205616461  0558925278  0733001998  0737104473  \
# UserId
# A00205921JHJK5X9LNP42         0.0         0.0         0.0         0.0
# A024581134CV80ZBLIZTZ         0.0         0.0         0.0         0.0
# A03056581JJIOL5FSKJY7         0.0         0.0         0.0         0.0
# A03099101ZRK4K607JVHH         0.0         0.0         0.0         0.0
# A0505229A7NSH3FRXRR4          0.0         0.0         0.0         0.0
#
# ProductId              0762451459  1304139212  1304139220  130414089X  \
# UserId
# A00205921JHJK5X9LNP42         0.0         0.0         0.0         0.0
# A024581134CV80ZBLIZTZ         0.0         0.0         0.0         0.0
# A03056581JJIOL5FSKJY7         0.0         0.0         0.0         0.0
# A03099101ZRK4K607JVHH         0.0         0.0         0.0         0.0
# A0505229A7NSH3FRXRR4          0.0         0.0         0.0         0.0
#
# ProductId              130414643X  1304146537  ...  B000052YPE  B000052YPF  \
# ...

# %%
ratings_utility_matrix.shape
# Out:
# (9697, 886)

# %%
X = ratings_utility_matrix.T
X.head()
# Out:
# UserId      A00205921JHJK5X9LNP42  A024581134CV80ZBLIZTZ  \
# ProductId
# 0205616461                    0.0                    0.0
# 0558925278                    0.0                    0.0
# 0733001998                    0.0                    0.0
# 0737104473                    0.0                    0.0
# 0762451459                    0.0                    0.0
#
# UserId      A03056581JJIOL5FSKJY7  A03099101ZRK4K607JVHH  \
# ProductId
# 0205616461                    0.0                    0.0
# 0558925278                    0.0                    0.0
# 0733001998                    0.0                    0.0
# 0737104473                    0.0                    0.0
# 0762451459                    0.0                    0.0
#
# UserId      A0505229A7NSH3FRXRR4  A05492663T95KW63BR75K  \
# ProductId
# 0205616461                   0.0                    0.0
# 0558925278                   0.0                    0.0
# 0733001998                   0.0                    0.0
# ...

# %%
SVD = TruncatedSVD(n_components=10)
decomposed_matrix = SVD.fit_transform(X)
decomposed_matrix.shape
# Out:
# (886, 10)

# %%
correlation_matrix = np.corrcoef(decomposed_matrix)
correlation_matrix.shape
# Out:
# (886, 886)

# %%
i = "0558925278" # for a random purchase made 

product_names = list(X.index)
product_ID = product_names.index(i)

correlation_product_ID = correlation_matrix[product_ID]
correlation_product_ID.shape
# Out:
# (886,)

# %%
plt.figure(figsize=(10, 8))
plt.imshow(correlation_matrix, cmap='coolwarm', interpolation='none', aspect='auto')
plt.colorbar()

plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# when we have a the information of past purchases we can make a a better recommendation using correlation matrix and collaborative filtering.

# %%
Recommend = list(X.index[correlation_product_ID > 0.90]) # recommendations for the purchase made
Recommend.remove(i) 
Recommend[0:9]
# Out:
# ['0205616461',
#  '0762451459',
#  '130414089X',
#  '1929099886',
#  '1987958179',
#  '3292000971',
#  '4057362797',
#  '4057362886',
#  '4057363823']
